# %% [markdown]
# # Set up

# %%
""" To activate environment (terminal):
$ conda activate breast_cancer_scrnaseq
To deactivate an active environment:
$ conda deactivate """
# Out:
# ' To activate environment (terminal):\n$ conda activate breast_cancer_scrnaseq\nTo deactivate an active environment:\n$ conda deactivate '

# %%
""" 
Activated environment in the terminal, installed pythong packages: conda install -c conda-forge -c bioconda \
  scanpy \
  anndata \
  pandas \
  numpy \
  scipy \
  scikit-learn \
  matplotlib \
  seaborn \
  networkx \
  jupyter \
  jupyterlab \
  harmonypy \
  decoupler
  
Also installed: pip install PyWGCNA """
# Out:
# ' \nActivated environment in the terminal, installed pythong packages: conda install -c conda-forge -c bioconda   scanpy   anndata   pandas   numpy   scipy   scikit-learn   matplotlib   seaborn   networkx   jupyter   jupyterlab   harmonypy   decoupler\n  \nAlso installed: pip install PyWGCNA '

# %%
""" checking everything: python -c "import scanpy; import anndata; import networkx; print('All packages installed successfully!')"

creating a project folder: mkdir ~/breast_cancer_analysis

verifing if created: ls ~/ | grep breast_cancer

moving to the project folder: cd ~/breast_cancer_analysis
"""
# Out:
# ' checking everything: python -c "import scanpy; import anndata; import networkx; print(\'All packages installed successfully!\')"\n\ncreating a project folder: mkdir ~/breast_cancer_analysis\n\nverifing if created: ls ~/ | grep breast_cancer\n\nmoving to the project folder: cd ~/breast_cancer_analysis\n'

# %%
""" mkdir data results wgcna_results figures notebooks

data =  downloaded datasets
results = analysis results
wgcna_results = wgcna analysis results
figures = plots and figures
notebooks = jupyter notebooks """
# Out:
# ' mkdir data results wgcna_results figures notebooks\n\ndata =  downloaded datasets\nresults = analysis results\nwgcna_results = wgcna analysis results\nfigures = plots and figures\nnotebooks = jupyter notebooks '

# %% [markdown]
# # Intro

# %%
import scanpy as sc
import anndata as ad
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Step 1: All packages imported successfully!")
print(f"Scanpy version: {sc.__version__}")
print(f"AnnData version: {ad.__version__}")

# Step 2: Create a test folder for data
import os
os.makedirs('../data', exist_ok=True)
print("\nStep 2: Data folder created at: ../data")

print("\nReady")
# Out:
# Step 1: All packages imported successfully!
# Scanpy version: 1.11.5
# AnnData version: 0.11.4
#
# Step 2: Data folder created at: ../data
#
# Ready
# /triumvirate/apps/.scratch/alexarol/ipykernel_3997263/250379574.py:9: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   print(f"Scanpy version: {sc.__version__}")
